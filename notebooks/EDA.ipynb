# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import csv

# %%
input_txt = r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\MachineLearningRating_v3.txt'  
output_csv = r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\output.csv'  

with open(input_txt, 'r', newline='') as infile, open(output_csv, 'w', newline='') as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)
    
    # Take the first row as the header
    header = next(reader)
    writer.writerow(header)
    
    # Write the remaining rows from the input file
    writer.writerows(reader)

# %%
# Replace 'path_to_your_txt_file.txt' with the path to your .txt file
txt_file_path = r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\MachineLearningRating_v3.txt'
# Replace 'output_csv_file.csv' with the desired output CSV file name
csv_file_path = r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\Data.csv'

# Assuming that your text file has tab-delimited values
df = pd.read_csv(txt_file_path, delimiter='\t', header=None)
df.to_csv(csv_file_path, index=False)

# %%
# Determine the maximum number of fields in any row
max_fields = 0
with open(r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\output.csv', 'r', newline='') as infile:
    reader = csv.reader(infile)
    max_fields = max(len(row) for row in reader)

# Now read the CSV into a DataFrame using the determined max_fields
data = pd.read_csv(r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\output.csv', delimiter='|')
print(data.head())
# Out:
# C:\Users\Abdulaziz\AppData\Local\Temp\ipykernel_6896\2690770360.py:8: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\Abdulaziz\Desktop\10 Academy\AlphaCare Insurance Solutions\Data\output.csv', delimiter='|')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# ...

# %%
data.head(10)
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
# 5               145247     12827  2015-01-01 00:00:00             True
# 6               145247     12827  2015-04-01 00:00:00             True
# 7               145247     12827  2015-06-01 00:00:00             True
# 8               145247     12827  2015-08-01 00:00:00             True
# 9               145245     12827  2015-03-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# ...

# %%
data.shape
# Out:
# (1000098, 52)

# %%
data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %% [markdown]
# ### Data Summarization:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %% [markdown]
# ### Data Sturcture

# %%
data['TransactionMonth'] = pd.to_datetime(data['TransactionMonth'])

# %%
data['RegistrationYear']=(data['RegistrationYear']).astype(int)

# %%
# for numerical columns
numerics = ['int64','int32', 'float64']
numeric_columns = data.select_dtypes(include=numerics)

# If you want the column names as a list:
numeric_column_names = numeric_columns.columns.tolist()

# If you want to create a new DataFrame with only numeric columns:
new_df = data[numeric_column_names]

# %%
new_df.head()
# Out:
#    UnderwrittenCoverID  PolicyID  PostalCode      mmcode  RegistrationYear  \
# 0               145249     12827        1459  44069150.0              2004
# 1               145249     12827        1459  44069150.0              2004
# 2               145249     12827        1459  44069150.0              2004
# 3               145255     12827        1459  44069150.0              2004
# 4               145255     12827        1459  44069150.0              2004
#
#    Cylinders  cubiccapacity  kilowatts  NumberOfDoors  CustomValueEstimate  \
# 0        6.0         2597.0      130.0            4.0             119300.0
# 1        6.0         2597.0      130.0            4.0             119300.0
# 2        6.0         2597.0      130.0            4.0             119300.0
# 3        6.0         2597.0      130.0            4.0             119300.0
# 4        6.0         2597.0      130.0            4.0             119300.0
#
# ...

# %%
# Calculate the variability for numerical features
new_df.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
new_df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'PostalCode', 'mmcode',
#        'RegistrationYear', 'Cylinders', 'cubiccapacity', 'kilowatts',
#        'NumberOfDoors', 'CustomValueEstimate', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'CalculatedPremiumPerTerm', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
# for catagorical column
catagory = ['bool', 'object']
catagorical_column = data.select_dtypes(include=catagory)

# If you want the column names as a list:
catagorical_column_names = catagorical_column.columns.tolist()

# If you want to create a new DataFrame with only numeric columns:
new_df_cat = data[catagorical_column_names]
new_df_cat.head()
# Out:
#    IsVATRegistered Citizenship          LegalType Title Language  \
# 0             True              Close Corporation    Mr  English
# 1             True              Close Corporation    Mr  English
# 2             True              Close Corporation    Mr  English
# 3             True              Close Corporation    Mr  English
# 4             True              Close Corporation    Mr  English
#
#                   Bank      AccountType  MaritalStatus         Gender  \
# 0  First National Bank  Current account  Not specified  Not specified
# 1  First National Bank  Current account  Not specified  Not specified
# 2  First National Bank  Current account  Not specified  Not specified
# 3  First National Bank  Current account  Not specified  Not specified
# 4  First National Bank  Current account  Not specified  Not specified
#
#         Country  ... CrossBorder TermFrequency  \
# 0  South Africa  ...         NaN       Monthly
# 1  South Africa  ...         NaN       Monthly
# ...

# %%
data['RegistrationYear']
# Out:
# 0          2004
# 1          2004
# 2          2004
# 3          2004
# 4          2004
#            ...
# 1000093    2013
# 1000094    2013
# 1000095    2013
# 1000096    2013
# 1000097    2013
# Name: RegistrationYear, Length: 1000098, dtype: int64

# %% [markdown]
# ### Data Quality Assessment:

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
data.shape
# Out:
# (1000098, 52)

# %%
# cleaning the data based on the datatype
# if catagorical we use mode
#if numerical we use mean
for i in catagorical_column_names:
    if data[i].isnull().any():  # Check if there is any null value in the column
        data[i].fillna(data[i].mode()[0], inplace=True)  # Fill with mode

for i in numeric_column_names:
    if data[i].isnull().any():  # Check if there is any null value in the column
        data[i].fillna(data[i].mean(), inplace=True)  # Fill with mean
# Out:
# C:\Users\Abdulaziz\AppData\Local\Temp\ipykernel_6896\1080884194.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].mode()[0], inplace=True)  # Fill with mode
# C:\Users\Abdulaziz\AppData\Local\Temp\ipykernel_6896\1080884194.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# make                              0
# Model                             0
# Cylinders                         0
# cubiccapacity                     0
# kilowatts                         0
# ...

# %%
final_data=data.to_csv('finaldata.csv', index=False)

# %%
final_data = pd.read_csv('finaldata.csv')
# Out:
# C:\Users\Abdulaziz\AppData\Local\Temp\ipykernel_6896\2132241183.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_data = pd.read_csv('finaldata.csv')

# %%
final_data.head(3)
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...         ExcessSelected CoverCategory   CoverType  \
# 0  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
# 1  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
# 2  Current account  ...  Mobility - Windscreen    Windscreen  Windscreen
#
#              CoverGroup              Section                          Product  \
# ...

# %%
# univariate analysis
for col in numeric_column_names[:50]:
    plt.figure(figsize=(10,5))
    plt.title(f'Histogram of {col}')
    data[col].hist(bins=30)
    plt.show()

# %%
# For categorical columns
for col in catagorical_column_names:
    plt.figure(figsize=(10,5))
    plt.title(f'Bar chart of {col}')
    data[col].value_counts().plot(kind='bar')
    plt.show()

# %%
# Bivariate or Multivariate Analysis:
# Correlations and Associations: Explore relationships between the monthly changes TotalPremium and TotalClaims as a function of ZipCode, using scatter plots and correlation matrices.

# %% [markdown]
# ### Data Comparison
# Trends Over Geography: Compare the change in insurance cover type, premium, auto make, etc.

# %%
data['TotalClaims'].dtype
# Out:
# dtype('float64')

# %%
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
data_copy = data.copy()

# Convert the entire 'TransactionMonth' column to datetime format
data_copy['TransactionMonth'] = pd.to_datetime(data_copy['TransactionMonth'])

# Set 'TransactionMonth' as the index
data_copy.set_index('TransactionMonth', inplace=True)

# Slice the first 50 samples
data_copy = data_copy.iloc[:50]

# Calculate monthly changes for 'TotalPremium' and 'TotalClaims'

# %%
df_monthly_changes = data_copy[['TotalPremium', 'TotalClaims']].resample('M').sum().diff()

# Scatter plots
plt.figure(figsize=(10, 5))
plt.scatter(df_monthly_changes['TotalPremium'], df_monthly_changes['TotalClaims'], color='orange')
plt.title('Scatter plot of monthly changes in TotalPremium vs TotalClaims')
plt.xlabel('TotalPremium')
plt.ylabel('TotalClaims')
plt.show()
# Out:
# C:\Users\Abdulaziz\AppData\Local\Temp\ipykernel_6896\1676208704.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_changes = data_copy[['TotalPremium', 'TotalClaims']].resample('M').sum().diff()

# %%
# Correlation matrix
corr_matrix = df_monthly_changes[['TotalPremium', 'TotalClaims']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation matrix of monthly changes in TotalPremium and TotalClaims')
plt.show()

# %%
# Group by country and cover type, calculate average premium
grouped = data[:50].groupby(['Country', 'CoverType'])['TotalPremium'].mean().reset_index()

# Pivot the data for better visualization
pivot_df = grouped.pivot(index='Country', columns='CoverType', values='TotalPremium')

# Plot
pivot_df.plot(kind='barh', stacked=True)
plt.title('Average Premium by Country and Cover Type')
plt.xlabel('Country')
plt.ylabel('Average Premium')
plt.show()

# %% [markdown]
# ### Outlier Detection:
# Use box plots to detect outliers in numerical data

# %%
selected_columns = data[numeric_column_names[:50]]

for column in selected_columns:
    selected_columns[column].plot(kind='box', color='orange')
    plt.title(f'Box plot of {column}')
    plt.xlabel('Column')
    plt.ylabel('Value')
    plt.show()

# %% [markdown]
# ## Visualization
# Produce 3 creative and beautiful plots that capture the key insight you gained from your EDA

# %%
# Scatter plot of monthly changes in TotalPremium vs TotalClaims
plt.figure(figsize=(10, 6))
plt.scatter(df_monthly_changes['TotalPremium'], df_monthly_changes['TotalClaims'], color='orange', alpha=0.7)
plt.title('Scatter Plot of Monthly Changes in TotalPremium vs TotalClaims', fontsize=16)
plt.xlabel('Monthly Change in TotalPremium', fontsize=14)
plt.ylabel('Monthly Change in TotalClaims', fontsize=14)
plt.grid(True)
plt.axhline(0, color='grey', lw=1, ls='--')
plt.axvline(0, color='grey', lw=1, ls='--')
plt.show()

# %%
# Correlation matrix heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Monthly Changes in TotalPremium and TotalClaims', fontsize=16)
plt.show()

# %%
# Stacked bar chart for average premium by country and cover type
plt.figure(figsize=(12, 8))
pivot_df.plot(kind='barh', stacked=True, ax=plt.gca(), color=sns.color_palette("husl", len(pivot_df.columns)))
plt.title('Average Premium by Country and Cover Type', fontsize=16)
plt.xlabel('Average Premium', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.legend(title='Cover Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
